# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geoplot as gplt
import geopandas as gp
import geoplot.crs as gcrs
# converts coordinate pairs into points that can be interpreted by geopandas
from shapely.geometry import Point

# %%
# reading the shapefile
sftracts = gp.read_file("/Users/daviderickson/projects/datasf/data/Analysis Neighborhoods - 2010 census tracts assigned to neighborhoods/geo_export_729f30ed-0972-44ec-b06d-34a8c3d7abe2.dbf")

# setting the census tract ID as index will make map creation easier later on!
sftracts.set_index("tractce10", inplace=True)

sftracts.head()
# Out:
#                  geoid             nhood    shape_area     shape_len  \
# tractce10
# 016400     06075016400      Hayes Valley  3.326589e+06   7589.679396
# 016100     06075016100  Western Addition  3.970259e+06   8525.808755
# 015900     06075015900  Western Addition  3.179072e+06   8000.966619
# 015500     06075015500         Japantown  3.364565e+06  12144.016761
# 015300     06075015300   Pacific Heights  2.515363e+06   6918.268026
#
#                                                     geometry
# tractce10
# 016400     POLYGON ((-122.4324669997095 37.77375700028448...
# 016100     POLYGON ((-122.4235409996432 37.77967400025458...
# 015900     POLYGON ((-122.4246870001921 37.78533500040309...
# 015500     POLYGON ((-122.4246870001921 37.78533500040309...
# 015300     POLYGON ((-122.4349179998128 37.78587599994257...

# %%
df = pd.read_csv('/Users/daviderickson/projects/datasf/data/Assessor_Historical_Secured_Property_Tax_Rolls.csv')
# Out:
# /Users/daviderickson/anaconda3/envs/property_tax_rolls/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns[25]
# Out:
# 'Percent of Ownership'

# %%
df.shape
# Out:
# (2238147, 43)

# %%
df.head(5)
# Out:
#    Closed Roll Year                     Property Location Parcel Number  \
# 0            2007.0  0000 0200 BRANNAN             ST0436       3774412
# 1            2016.0  0000 1207 INDIANA             ST0004       4228041
# 2            2010.0  0000 0383 SITUS TO BE ASSIGNEDST0000       0041102
# 3            2007.0  0000 0708 NORTH POINT         STT  1       0024038
# 4            2016.0  0000 0188 MARY TERESA         ST0000      5054A152
#
#    Block  Lot  Volume Number Use Code             Use Definition  \
# 0   3774  412             25     SRES  Single Family Residential
# 1   4228  041             27     SRES  Single Family Residential
# 2   0041  102              1     COMR          Commercial Retail
# 3   0024  038              1     SRES  Single Family Residential
# 4  5054A  152             30     SRES  Single Family Residential
#
#   Property Class Code Property Class Code Definition  ...  \
# 0                   Z                    Condominium  ...
# ...

# %%
df.describe()
# Out:
#        Closed Roll Year  Volume Number  Year Property Built  \
# count      2.238146e+06   2.238147e+06         2.064000e+06
# mean       2.012061e+03   2.063252e+01         1.941636e+03
# std        3.164951e+00   1.288068e+01         5.587058e+01
# min        2.007000e+03   1.000000e+00         1.024000e+03
# 25%        2.009000e+03   9.000000e+00         1.914000e+03
# 50%        2.012000e+03   1.900000e+01         1.935000e+03
# 75%        2.015000e+03   3.200000e+01         1.962000e+03
# max        2.017000e+03   4.400000e+01         9.185000e+03
#
#        Number of Bathrooms  Number of Bedrooms  Number of Rooms  \
# count         2.238147e+06        2.238147e+06     2.238147e+06
# mean          2.364135e+00        1.048956e+00     7.823049e+00
# std           8.784859e+00        1.069431e+01     2.376514e+01
# min           0.000000e+00        0.000000e+00     0.000000e+00
# 25%           1.000000e+00        0.000000e+00     4.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['Closed Roll Year', 'Property Location', 'Parcel Number', 'Block',
#        'Lot', 'Volume Number', 'Use Code', 'Use Definition',
#        'Property Class Code', 'Property Class Code Definition',
#        'Year Property Built', 'Number of Bathrooms', 'Number of Bedrooms',
#        'Number of Rooms', 'Number of Stories', 'Number of Units',
#        'Zoning Code', 'Construction Type', 'Lot Depth', 'Lot Frontage',
#        'Property Area', 'Basement Area', 'Lot Area', 'Lot Code',
#        'Tax Rate Area Code', 'Percent of Ownership', 'Exemption Code',
#        'Exemption Code Definition', 'Status Code', 'Misc Exemption Value',
#        'Homeowner Exemption Value', 'Current Sales Date',
#        'Assessed Fixtures Value', 'Assessed Improvement Value',
#        'Assessed Land Value', 'Assessed Personal Property Value',
#        'Assessor Neighborhood District', 'Assessor Neighborhood Code',
#        'Assessor Neighborhood', 'Supervisor District', 'Analysis Neighborhood',
# ...

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in df['the_geom']:
    # Try to,
    try:
        # Split the row by comma, convert to float, and append
        # everything before the comma to lat
        lon.append(float(row.split(',')[0].split('(')[1]))
        # Split the row by comma, convert to float, and append
        # everything after the comma to lon
        lat.append(float(row.split(',')[1].split(')')[0]))
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
df['latitude'] = lat
df['longitude'] = lon

# %%
# convert coords to points
df["Coordinates"] = (df[["latitude", "longitude"]]
                               .apply(tuple, axis=1)
                               .apply(Point)
                              ) 
# convert dataframe to geodataframe
df = gp.GeoDataFrame(df, geometry="Coordinates")

# %%
df.head()
# Out:
#    Closed Roll Year                     Property Location Parcel Number  \
# 0            2007.0  0000 0200 BRANNAN             ST0436       3774412
# 1            2016.0  0000 1207 INDIANA             ST0004       4228041
# 2            2010.0  0000 0383 SITUS TO BE ASSIGNEDST0000       0041102
# 3            2007.0  0000 0708 NORTH POINT         STT  1       0024038
# 4            2016.0  0000 0188 MARY TERESA         ST0000      5054A152
#
#    Block  Lot  Volume Number Use Code             Use Definition  \
# 0   3774  412             25     SRES  Single Family Residential
# 1   4228  041             27     SRES  Single Family Residential
# 2   0041  102              1     COMR          Commercial Retail
# 3   0024  038              1     SRES  Single Family Residential
# 4  5054A  152             30     SRES  Single Family Residential
#
#   Property Class Code Property Class Code Definition  ...  \
# 0                   Z                    Condominium  ...
# ...

# %%
# 
df.crs = sftracts.crs # Making sure the map projections of both geodataframes are the same
df_joined = gp.sjoin(df, sftracts) # joining the geodataframes on its spatial geometries
df_joined.rename(columns={"index_right":"tractce10"}, inplace=True)
df_joined.iloc[:,::-1].head()
df_joined.head()
# Out:
#     Closed Roll Year                      Property Location Parcel Number  \
# 0             2007.0   0000 0200 BRANNAN             ST0436       3774412
# 6             2015.0   0000 0199 NEW MONTGOMERY      ST0601       3722136
# 15            2016.0  0000 0501 BEALE               ST0009B       3771049
# 17            2010.0   0000 0077 DOW                 PL0904       3750566
# 30            2012.0   0000 0355 1ST                 STS601       3748213
#
#    Block  Lot  Volume Number Use Code             Use Definition  \
# 0   3774  412             25     SRES  Single Family Residential
# 6   3722  136             25     SRES  Single Family Residential
# 15  3771  049             25     SRES  Single Family Residential
# 17  3750  566             25     SRES  Single Family Residential
# 30  3748  213             25     SRES  Single Family Residential
#
#    Property Class Code Property Class Code Definition  ...  \
# 0                    Z                    Condominium  ...
# ...

# %%
land_value = df['Assessed Land Value']
plt.scatter('latitude', 'longitude', data=df, c=np.log(land_value))
plt.colorbar()
'lat, lon backwards?'
# Out:
# /Users/daviderickson/anaconda3/envs/property_tax_rolls/lib/python3.6/site-packages/pandas/core/series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 'lat, lon backwards?'

# %%
df['Assessed Land Value'].describe()
# Out:
# count    2.238146e+06
# mean     3.994016e+05
# std      2.269509e+06
# min      0.000000e+00
# 25%      5.093500e+04
# 50%      1.966560e+05
# 75%      4.119580e+05
# max      5.835724e+08
# Name: Assessed Land Value, dtype: float64

# %%
df['Closed Roll Year'].describe()
# Out:
# count    2.238146e+06
# mean     2.012061e+03
# std      3.164951e+00
# min      2.007000e+03
# 25%      2.009000e+03
# 50%      2.012000e+03
# 75%      2.015000e+03
# max      2.017000e+03
# Name: Closed Roll Year, dtype: float64

# %%
ax = gplt.polyplot(sftracts.geometry, projection = gcrs.LambertConformal(),
                   figsize=(12,8), edgecolor="k")
ax.set_title("Census Tract Boundaries in San Francisco", fontweight="bold", fontsize=16)
plt.show()

# %%
df_joined.columns
# Out:
# Index(['Closed Roll Year', 'Property Location', 'Parcel Number', 'Block',
#        'Lot', 'Volume Number', 'Use Code', 'Use Definition',
#        'Property Class Code', 'Property Class Code Definition',
#        'Year Property Built', 'Number of Bathrooms', 'Number of Bedrooms',
#        'Number of Rooms', 'Number of Stories', 'Number of Units',
#        'Zoning Code', 'Construction Type', 'Lot Depth', 'Lot Frontage',
#        'Property Area', 'Basement Area', 'Lot Area', 'Lot Code',
#        'Tax Rate Area Code', 'Percent of Ownership', 'Exemption Code',
#        'Exemption Code Definition', 'Status Code', 'Misc Exemption Value',
#        'Homeowner Exemption Value', 'Current Sales Date',
#        'Assessed Fixtures Value', 'Assessed Improvement Value',
#        'Assessed Land Value', 'Assessed Personal Property Value',
#        'Assessor Neighborhood District', 'Assessor Neighborhood Code',
#        'Assessor Neighborhood', 'Supervisor District', 'Analysis Neighborhood',
# ...

# %%
# land_value_by_tract = gp.GeoDataFrame((df
#                                      .tractce10.value_counts()
#                                      .to_frame()
#                                      .rename(columns={"tractce10":"Incidents"})
#                                     ).merge(sftracts.geometry.to_frame(),
#                                             left_index=True, right_index=True)
#                                    )
# drug_inc_by_tract.head()

# %%
df_groupby_nhood = df_joined.groupby(by='Analysis Neighborhood').mean()

# %%
df_groupby_nhood.head()
# Out:
#                        Closed Roll Year  Volume Number  Year Property Built  \
# Analysis Neighborhood
# Bayview Hunters Point       2012.124666      30.646635          1954.393609
# Bernal Heights              2012.018163      33.873737          1928.697692
# Castro/Upper Market         2012.083478      21.047826          1928.370819
# Chinatown                   2012.022899       1.987515          1934.773760
# Excelsior                   2012.003633      36.699027          1936.746711
#
#                        Number of Bathrooms  Number of Bedrooms  \
# Analysis Neighborhood
# Bayview Hunters Point             1.545634            0.891812
# Bernal Heights                    1.622283            0.963739
# Castro/Upper Market               2.324171            0.909271
# Chinatown                         4.622873            0.496798
# Excelsior                         1.529839            0.731971
#
#                        Number of Rooms  Number of Stories  Number of Units  \
# ...

# %%
# convert coords to points
df_groupby_nhood["Coordinates"] = (df_groupby_nhood[["latitude", "longitude"]]
                               .apply(tuple, axis=1)
                               .apply(Point)
                              ) 
# convert dataframe to geodataframe
df_groupby_nhood = gp.GeoDataFrame(df_groupby_nhood, geometry="Coordinates")

# %%
df_joined.crs = sftracts.crs # Making sure the map projections of both geodataframes are the same
drug_inc_by_tract = gp.sjoin(df_joined, sftracts) # joining the geodataframes on its spatial geometries
drug_inc_by_tract.rename(columns={"index_right":"tractce10"}, inplace=True)
drug_inc_by_tract.iloc[:,::-1].head()
# Out:
#     shape_len_right  shape_area_right                     nhood_right  \
# 0      26864.752027      1.797075e+07  Financial District/South Beach
# 6      26864.752027      1.797075e+07  Financial District/South Beach
# 15     26864.752027      1.797075e+07  Financial District/South Beach
# 17     26864.752027      1.797075e+07  Financial District/South Beach
# 30     26864.752027      1.797075e+07  Financial District/South Beach
#
#     geoid_right tractce10  shape_len_left  shape_area_left  \
# 0   06075061500    061500    26864.752027     1.797075e+07
# 6   06075061500    061500    26864.752027     1.797075e+07
# 15  06075061500    061500    26864.752027     1.797075e+07
# 17  06075061500    061500    26864.752027     1.797075e+07
# 30  06075061500    061500    26864.752027     1.797075e+07
#
#                         nhood_left   geoid_left tractce10  ...  \
# 0   Financial District/South Beach  06075061500    061500  ...
# ...

# %%
drug_inc_by_tract.head()
# Out:
#     Closed Roll Year                      Property Location Parcel Number  \
# 0             2007.0   0000 0200 BRANNAN             ST0436       3774412
# 6             2015.0   0000 0199 NEW MONTGOMERY      ST0601       3722136
# 15            2016.0  0000 0501 BEALE               ST0009B       3771049
# 17            2010.0   0000 0077 DOW                 PL0904       3750566
# 30            2012.0   0000 0355 1ST                 STS601       3748213
#
#    Block  Lot  Volume Number Use Code             Use Definition  \
# 0   3774  412             25     SRES  Single Family Residential
# 6   3722  136             25     SRES  Single Family Residential
# 15  3771  049             25     SRES  Single Family Residential
# 17  3750  566             25     SRES  Single Family Residential
# 30  3748  213             25     SRES  Single Family Residential
#
#    Property Class Code Property Class Code Definition  ...  tractce10  \
# ...

# %%
# I think This block should be the answer, but it never finishes running
"""

ax = gplt.choropleth(drug_inc_by_tract, projection=gcrs.LambertConformal(), hue="Assessed Land Value",
                     cmap="coolwarm", k=None, linewidth=0, figsize=(10,8), legend=True)
gplt.polyplot(sftracts.geometry, projection = gcrs.LambertConformal(), edgecolor="k",
              linewidth=1, ax=ax)
ax.set_title("Mean Assesed Land Value by Tract",
             fontweight="bold", fontsize=16)
plt.show()

"""

# %%
drug_inc_by_tract = gp.GeoDataFrame((df_joined
                                    ).merge(sftracts.geometry.to_frame(),
                                            left_index=True, right_index=True)
                                   )
drug_inc_by_tract.head()

# %%
# 
df_groupby_nhood.crs = sftracts.crs # Making sure the map projections of both geodataframes are the same
df_agg_tract = gp.sjoin(df_groupby_nhood, sftracts) # joining the geodataframes on its spatial geometries
df_agg_tract.rename(columns={"index_right":"tractce10"}, inplace=True)
df_agg_tract.iloc[:,::-1].head()
df_agg_tract.head()

# %%
df_agg_tract['Assessed Land Value'].hist()

# %%
ax = gplt.choropleth(df_agg_tract, projection=gcrs.LambertConformal(), hue="Assessed Land Value",
                     cmap="coolwarm", k=None, linewidth=0, figsize=(10,8), legend=True)
gplt.polyplot(sftracts.geometry, projection = gcrs.LambertConformal(), edgecolor="k",
              linewidth=1, ax=ax)
ax.set_title("Mean Assesed Land Value by Tract",
             fontweight="bold", fontsize=16)
plt.show()
